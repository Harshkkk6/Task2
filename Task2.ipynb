# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshkkk6/Task2/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data cleaning and Preprocessing

# %% [markdown]
# Importing dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset to a pandas dataframe
titanic_data = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#rows and columns
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#finding missing values
titanic_data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#dropping cabin section as its not important
titanic_data = titanic_data.drop(columns ='Cabin')

# %%
titanic_data['Age'].fillna(titanic_data['Age'].mean(), inplace=True)
# Out:
# <ipython-input-8-9bcc38b8c29e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_data['Age'].fillna(titanic_data['Age'].mean(), inplace=True)

# %%
titanic_data.shape
# Out:
# (891, 11)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %% [markdown]
# *   0 --> not survived
# *   1 --> survived

# %%
#counting the number of people survived
survived = titanic_data['Survived'].value_counts()
survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Group the data by sex and survival status
survived_by_sex = titanic_data.groupby(['Sex', 'Survived'])['Survived'].count()

# Print the results
survived_by_sex
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
# Group the data by Pclass and survival status
survived_by_class = titanic_data.groupby(['Pclass','Survived'])['Survived'].count()

# Print the results
survived_by_class
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
# Calculate the average age of passengers who survived and didn't survive
average_age_by_survival = titanic_data.groupby('Survived')['Age'].mean()

# Print the results
average_age_by_survival
# Out:
# Survived
# 0    30.415100
# 1    28.549778
# Name: Age, dtype: float64

# %%
#describing the data
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Encoding categorical features using one-hot encoding
titanic_data = pd.get_dummies(titanic_data, columns=['Sex', 'Embarked'], drop_first=True)

# Display the updated DataFrame
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500      True       False        True
# 1          PC 17599  71.2833     False       False       False
# 2  STON/O2. 3101282   7.9250     False       False        True
# 3            113803  53.1000     False       False        True
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Assuming 'titanic_data' is your DataFrame
numerical_features = ['Age', 'Fare']  # Add other numerical columns as needed

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to your numerical features
scaler.fit(titanic_data[numerical_features])

# Transform the numerical features
titanic_data[numerical_features] = scaler.transform(titanic_data[numerical_features])

# Display the updated DataFrame
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name       Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris -0.592481      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  0.638789      1      0
# 2                             Heikkinen, Miss. Laina -0.284663      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.407926      1      0
# 4                           Allen, Mr. William Henry  0.407926      0      0
#
#              Ticket      Fare  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171 -0.502445      True       False        True
# 1          PC 17599  0.786845     False       False       False
# 2  STON/O2. 3101282 -0.488854     False       False        True
# ...

# %%
numerical_features = ['Age', 'Fare']

def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_filtered

for col in numerical_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=titanic_data[col])
    plt.title(f'Boxplot of {col} before outlier removal')
    plt.show()
    titanic_data = remove_outliers_iqr(titanic_data,col)
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=titanic_data[col])
    plt.title(f'Boxplot of {col} after outlier removal')
    plt.show()

# %%
# Display summary statistics for numerical columns
print(titanic_data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   718.000000  718.000000  718.000000  718.000000  718.000000
# mean    447.883008    0.334262    2.512535   -0.095144    0.413649
# std     259.549777    0.472061    0.715818    0.772200    0.855001
# min       1.000000    0.000000    1.000000   -2.054613    0.000000
# 25%     220.250000    0.000000    2.000000   -0.592481    0.000000
# 50%     447.500000    0.000000    3.000000    0.000000    0.000000
# 75%     673.500000    1.000000    3.000000    0.244398    1.000000
# max     891.000000    1.000000    3.000000    1.870059    5.000000
#
#             Parch        Fare
# count  718.000000  718.000000
# mean     0.317549   -0.302242
# std      0.784792    0.266674
# min      0.000000   -0.648422
# 25%      0.000000   -0.489568
# 50%      0.000000   -0.411839
# 75%      0.000000   -0.126366
# max      6.000000    0.587429

# %%
import matplotlib.pyplot as plt
for col in numerical_features:
    plt.figure(figsize=(8, 6))
    sns.histplot(titanic_data[col], kde=True)  # Use histplot for histograms
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
import matplotlib.pyplot as plt
# Create the pairplot
sns.pairplot(titanic_data)
plt.show()

# Calculate the correlation matrix, excluding non-numeric columns
# Select only numeric columns for correlation calculation
numeric_data = titanic_data.select_dtypes(include=np.number)
correlation_matrix = numeric_data.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Titanic Dataset Features')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Correlation analysis already performed in the provided code.
# The heatmap visualizes the correlation between numerical features.
# Strong positive or negative correlations indicate potential relationships.
# Features with low correlation might be less relevant to the target variable.

# Further analysis could include:
# - Investigating the relationship between 'Survived' and other features
#   using scatter plots, box plots, or violin plots.
# - Exploring interactions between features.
# - Applying dimensionality reduction techniques (PCA) if necessary.


# Example of further analysis: survival rate based on age groups
# Create age groups
titanic_data['Age_Group'] = pd.cut(titanic_data['Age'], bins=[0, 18, 30, 50, 100], labels=['0-18', '19-30', '31-50', '50+'])

# Calculate survival rate for each age group
age_survival_rate = titanic_data.groupby('Age_Group')['Survived'].mean()
print(age_survival_rate)

# Visualize the survival rate by age group
plt.figure(figsize=(8, 6))
sns.barplot(x=age_survival_rate.index, y=age_survival_rate.values)
plt.title('Survival Rate by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.show()
# Out:
# Age_Group
# 0-18     0.337553
# 19-30         NaN
# 31-50         NaN
# 50+           NaN
# Name: Survived, dtype: float64
# <ipython-input-23-f422a1c1ce74>:20: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survival_rate = titanic_data.groupby('Age_Group')['Survived'].mean()

# %% [markdown]
# # Based on the provided code and generated visualizations:
#
# # 1. Survival Correlation:
# #    - The heatmap shows the correlation between numerical features and the 'Survived' column.
# #    - Features with higher absolute correlation values (closer to 1 or -1) are more strongly associated with survival.  Examine those features closely.
#
# # 2. Age and Survival:
# #    - The analysis of survival rate by age group reveals that younger passengers (0-18) might have had a higher survival rate compared to older groups (although this is dependent on the dataset).
#
# # 3. Passenger Class and Survival:
# #    - (From the earlier groupby operation) Passengers in higher classes (Pclass 1) likely had better survival rates than those in lower classes.
#
#
# # 4. Sex and Survival:
# #    - (From the earlier groupby operation)  Females likely exhibited a significantly higher survival rate than males.
#
# # 5. Fare and Survival:
# #    -  A potential correlation between Fare and survival could be present based on the heatmap.  Higher fares might indicate better cabin locations or class, potentially influencing survival.
#
# # Further Steps Based on Visualizations:
# # - Investigate potential interactions between features. For instance, does the survival rate for females vary by passenger class?  Create visualizations (e.g., grouped bar charts) to examine such interactions.
# # - Consider more complex visualizations like violin plots or boxenplots to understand the distribution of numerical features based on the 'Survived' column.
# # - Look for non-linear relationships in the data, which might not be captured by correlation coefficients.
